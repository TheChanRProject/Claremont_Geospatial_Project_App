# %%
from os import getcwd, listdir, chdir 
chdir("../../..")

# %%
from time import sleep
from os import getcwd, listdir
from geospatial_project.src.scripts.nearest_restaurants_schools_oop import nearest_restaurants
from IPython.display import display
import pandas as pd

school_path = getcwd() + "/geospatial_project/data/csv"

nr = nearest_restaurants(school_path)
nr.view_schools()
nr.make_coordinates()

nr_results = nr.search_results(query='restaurants', radius=10, now=False)
# Rather than Putting Page Result 2 and 3 in the Class, add them from the instantiated object
count = 0

school_names = nr.df['school_name'].tolist()

result_dict = {}
while count < len(nr_results):
    result = nr_results[count]
    sleep(3)
    result2 = nr.gmaps.places(query='restaurants', page_token=result['next_page_token'])
    sleep(3)
    result3 = nr.gmaps.places(query='restaurants', page_token=result2['next_page_token'])
    result_dict[school_names[count]] = [result, result2, result3]
    count += 1

nr_frame_dict = nr.frame_process(result_dict)

nr_frame_dict['Arcadia High School']

haversine_results = nr.haversine_distance(nr_frame_dict, 'm')

google_results = nr.google_distance(nr_frame_dict, transporation_mode='walking')

for school in google_results.keys():
    display(google_results[school].dropna().reset_index().drop('index', axis=1))
# Out:
#    distances walking duration
# 0     0.4 km           5 mins
# 1     0.4 km           5 mins
# 2     0.7 km           9 mins
# 3     0.7 km           9 mins
# 4     0.6 km           8 mins
# 5     1.7 km          21 mins
# 6     0.4 km           5 mins
# 7     1.2 km          15 mins
# 8     0.7 km           9 mins
# 9     0.6 km           8 mins
# 10    0.4 km           5 mins
# 11    1.0 km          12 mins
# 12    0.5 km           7 mins
# 13    1.7 km          21 mins
# 14    1.6 km          19 mins
# 15    0.7 km          10 mins
# 16    1.9 km          23 mins
# 17    0.5 km           7 mins
# 18    1.6 km          19 mins
# 19    3.4 km          43 mins
# 20    0.4 km           5 mins
# 21    3.2 km          40 mins
# 22    1.7 km          21 mins
# 23    0.6 km           9 mins
# 24    1.7 km          21 mins
# 25    1.6 km          19 mins
# 26    3.9 km          47 mins
# 27    0.7 km           9 mins
# 28    2.3 km          28 mins
# 29    2.3 km          28 mins
# 30    0.6 km           8 mins
# 31    0.7 km           9 mins
# 32    2.4 km          30 mins
# 33    3.1 km          37 mins
# 34    0.6 km           8 mins
# 35    2.3 km          28 mins
# 36    3.0 km          36 mins
# 37    2.2 km          27 mins
# 38    2.4 km          29 mins
# 39    0.4 km           5 mins
# 40    3.9 km          47 mins
# 41    2.4 km          29 mins
# 42    2.5 km          30 mins
# 43    3.6 km          42 mins
# 44    4.4 km          56 mins
# 45    3.8 km          46 mins
# 46    2.6 km          31 mins
# 47    2.6 km          31 mins
# 48    3.1 km          38 mins
# 49    3.9 km          47 mins
# 50    4.9 km    1 hour 0 mins
# 51    1.6 km          19 mins
# 52    1.6 km          19 mins
# 53    3.4 km          40 mins
# 54    2.2 km          26 mins
# 55    2.0 km          24 mins
# 56    2.1 km          26 mins
# 57    3.8 km          45 mins
# 58    4.3 km          51 mins
# 59    3.6 km          43 mins
#    distances walking duration
# 0     2.4 km          30 mins
# 33    2.7 km          34 mins
# 34    2.5 km          30 mins
# 35    5.8 km   1 hour 12 mins
# 36    2.7 km          34 mins
# 37    4.2 km          53 mins
# 38    3.0 km          39 mins
# 39    3.5 km          45 mins
# 40    1.1 km          13 mins
# 41    4.3 km          53 mins
# 42    1.1 km          14 mins
# 43    0.9 km          11 mins
# 44    6.9 km   1 hour 26 mins
# 45    3.0 km          38 mins
# 46    2.6 km          31 mins
# 47    5.7 km   1 hour 11 mins
# 48    8.4 km   1 hour 45 mins
# 49    3.9 km          48 mins
# 50    2.6 km          33 mins
# 51    8.5 km   1 hour 44 mins
# 52    7.2 km   1 hour 30 mins
# 53    3.9 km          48 mins
# 54    5.7 km   1 hour 14 mins
# 55    8.4 km   1 hour 45 mins
# 56    5.9 km   1 hour 12 mins
# 57    7.6 km   1 hour 33 mins
# 58    4.2 km          53 mins
# 59    8.7 km   1 hour 49 mins

# %%
myMergeDict = {}

for key in nr_frame_dict.keys():
    myList = []
    myList.append(key)
    myMerge = pd.concat([google_results[key],nr_frame_dict[key]])
    print(myMerge)
# Out:
# D:\Radh\Python\anaconda\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#    distances  latitudes  longitudes                             names  \
# 0     0.4 km        NaN         NaN                               NaN
# 1     0.4 km        NaN         NaN                               NaN
# 2     0.7 km        NaN         NaN                               NaN
# 3     0.7 km        NaN         NaN                               NaN
# 4     0.6 km        NaN         NaN                               NaN
# ..       ...        ...         ...                               ...
# 55       NaN  34.258511 -118.539134           L & L Hawaiian Barbecue
# 56       NaN  34.258534 -118.539443                      Kababe Grill
# 57       NaN  34.237744 -118.536388            The Habit Burger Grill
# 58       NaN  34.231563 -118.535793  Joyce's Coffee Shop & Restaurant
# 59       NaN  34.238994 -118.536474                    Falafel Palace
#
#     price_levels  ratings  total_user_ratings walking duration
# 0            NaN      NaN                 NaN           5 mins
# 1            NaN      NaN                 NaN           5 mins
# 2            NaN      NaN                 NaN           9 mins
# 3            NaN      NaN                 NaN           9 mins
# 4            NaN      NaN                 NaN           8 mins
# ..           ...      ...                 ...              ...
# 55           1.0      4.0               192.0              NaN
# 56           NaN      4.9                37.0              NaN
# 57           1.0      4.4               803.0              NaN
# 58           1.0      4.5               301.0              NaN
# 59           1.0      4.5               345.0              NaN
#
# [120 rows x 8 columns]
#    distances  latitudes  longitudes  \
# 0     2.4 km        NaN         NaN
# 1     1.7 km        NaN         NaN
# 2     2.0 km        NaN         NaN
# 3     2.2 km        NaN         NaN
# 4     1.9 km        NaN         NaN
# ..       ...        ...         ...
# 55       NaN  34.139588 -118.023550
# 56       NaN  34.126895 -118.053641
# 57       NaN  34.134035 -118.051888
# 58       NaN  34.134700 -118.051588
# 59       NaN  34.126600 -118.055177
#
#                                                 names  price_levels  ratings  \
# 0                                                 NaN           NaN      NaN
# 1                                                 NaN           NaN      NaN
# 2                                                 NaN           NaN      NaN
# 3                                                 NaN           NaN      NaN
# 4                                                 NaN           NaN      NaN
# ..                                                ...           ...      ...
# 55                             Nirvana Indian Cuisine           2.0      4.4
# 56                            Ikka Sizzling Pot 壹家砂锅馆           NaN      4.8
# 57            California Pizza Kitchen at Santa Anita           2.0      4.3
# 58  Porkfolio Korean BBQ / 自助韓國烤肉 吃到飽/All you can ...           NaN      1.0
# 59                                               IHOP           1.0      4.1
#
#     total_user_ratings walking duration
# 0                  NaN          30 mins
# 1                  NaN          22 mins
# 2                  NaN          26 mins
# 3                  NaN          28 mins
# 4                  NaN          24 mins
# ..                 ...              ...
# 55               214.0              NaN
# 56                12.0              NaN
# 57               412.0              NaN
# 58                 2.0              NaN
# 59               393.0              NaN
#
# [120 rows x 8 columns]
#    distances  latitudes  longitudes                                     names  \
# 0     0.8 km        NaN         NaN                                       NaN
# 1        NaN        NaN         NaN                                       NaN
# 2        NaN        NaN         NaN                                       NaN
# 3        NaN        NaN         NaN                                       NaN
# 4        NaN        NaN         NaN                                       NaN
# ..       ...        ...         ...                                       ...
# 55       NaN  35.911300  -79.061006  Mediterranean Deli, Bakery, and Catering
# 56       NaN  35.927977  -79.028053                                   bartaco
# 57       NaN  35.906380  -79.089200              Hong Kong Chinese Restaurant
# 58       NaN  35.910933  -79.073867                                  Provence
# 59       NaN  35.912946  -79.055358      Top of the Hill Restaurant & Brewery
#
#     price_levels  ratings  total_user_ratings walking duration
# 0            NaN      NaN                 NaN          10 mins
# 1            NaN      NaN                 NaN              NaN
# 2            NaN      NaN                 NaN              NaN
# 3            NaN      NaN                 NaN              NaN
# 4            NaN      NaN                 NaN              NaN
# ..           ...      ...                 ...              ...
# 55           2.0      4.6              1404.0              NaN
# 56           2.0      4.5               483.0              NaN
# 57           1.0      4.4               155.0              NaN
# 58           3.0      4.3               119.0              NaN
# 59           2.0      4.4               542.0              NaN
#
# [120 rows x 8 columns]
#    distances  latitudes  longitudes                                   names  \
# 0     1.1 km        NaN         NaN                                     NaN
# 1     1.0 km        NaN         NaN                                     NaN
# 2     1.4 km        NaN         NaN                                     NaN
# 3     0.9 km        NaN         NaN                                     NaN
# 4     0.9 km        NaN         NaN                                     NaN
# ..       ...        ...         ...                                     ...
# 55       NaN  33.651815 -117.746340                           Tender Greens
# 56       NaN  33.697787 -117.827746                               Kettlebar
# 57       NaN  33.681529 -117.840481  Andrei's Conscious Cuisine & Cocktails
# 58       NaN  33.725535 -117.788682                             Chick-fil-A
# 59       NaN  33.650860 -117.742113                       Habana Restaurant
#
#     price_levels  ratings  total_user_ratings walking duration
# 0            NaN      NaN                 NaN          13 mins
# 1            NaN      NaN                 NaN          12 mins
# 2            NaN      NaN                 NaN          17 mins
# 3            NaN      NaN                 NaN          11 mins
# 4            NaN      NaN                 NaN          11 mins
# ..           ...      ...                 ...              ...
# 55           2.0      4.4               407.0              NaN
# 56           2.0      4.5               128.0              NaN
# 57           3.0      4.5               358.0              NaN
# 58           1.0      4.6               861.0              NaN
# 59           2.0      4.4              1048.0              NaN
#
# [120 rows x 8 columns]
